# %%
import numpy as np
import pandas as pd

# %%
university=pd.read_csv("C:\\Users\\ASUS\\machine-learning-projects\\university-recommendation\\cwurData.csv")

# %%
university.head()#display data
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# 0             1          1          1           NaN        5  100.00  2012
# 1            12          4          4           NaN        1   91.67  2012
# 2             4          2          2           NaN       15   89.50  2012
# 3            16         16         11           NaN       50   86.17  2012
# 4            37         22         22           NaN       18   85.21  2012

# %%
university_rating_num = university.groupby('institution').count()['score']#Number of scores for particular institution,we will be classifying based on gre score and rating
university_rating_num = university_rating_num.rename('University Education Quality').reset_index()#rename 
university_rating_num
# Out:
#                                    institution  University Education Quality
# 0     AGH University of Science and Technology                             2
# 1                           Aalborg University                             2
# 2                             Aalto University                             2
# 3                            Aarhus University                             2
# 4                       Aberystwyth University                             2
# ...                                        ...                           ...
# 1019                    École centrale de Lyon                             1
# 1020          École normale supérieure - Paris                             4
# 1021        École normale supérieure de Cachan                             1
# 1022          École normale supérieure de Lyon                             2
# 1023                         Örebro University                             2
#
# [1024 rows x 2 columns]

# %%
university_rating_avg = university.groupby('institution').mean()['score'].reset_index()
university_rating_avg.rename(columns={'score': 'University Education Quality Average'}, inplace=True)
university_rating_avg
# Out:
#                                    institution  \
# 0     AGH University of Science and Technology
# 1                           Aalborg University
# 2                             Aalto University
# 3                            Aarhus University
# 4                       Aberystwyth University
# ...                                        ...
# 1019                    École centrale de Lyon
# 1020          École normale supérieure - Paris
# 1021        École normale supérieure de Cachan
# 1022          École normale supérieure de Lyon
# 1023                         Örebro University
#
#       University Education Quality Average
# 0                                   44.485
# 1                                   44.710
# 2                                   45.340
# 3                                   49.910
# 4                                   44.375
# ...                                    ...
# 1019                                44.150
# 1020                                53.830
# 1021                                44.330
# 1022                                45.060
# 1023                                44.570
#
# [1024 rows x 2 columns]

# %%
university_popularity_df = university_rating_num.merge(university_rating_avg, on="institution")
university_popularity_df
# Out:
#                                    institution  University Education Quality  \
# 0     AGH University of Science and Technology                             2
# 1                           Aalborg University                             2
# 2                             Aalto University                             2
# 3                            Aarhus University                             2
# 4                       Aberystwyth University                             2
# ...                                        ...                           ...
# 1019                    École centrale de Lyon                             1
# 1020          École normale supérieure - Paris                             4
# 1021        École normale supérieure de Cachan                             1
# 1022          École normale supérieure de Lyon                             2
# 1023                         Örebro University                             2
#
#       University Education Quality Average
# 0                                   44.485
# 1                                   44.710
# 2                                   45.340
# 3                                   49.910
# 4                                   44.375
# ...                                    ...
# 1019                                44.150
# 1020                                53.830
# 1021                                44.330
# 1022                                45.060
# 1023                                44.570
#
# [1024 rows x 3 columns]

# %%
popular_university_df=university_popularity_df[university_popularity_df['University Education Quality Average'] >= 80]#selecting top universities

# %%
popular_university_df
# Out:
#                                institution  University Education Quality  \
# 53      California Institute of Technology                             4
# 96                     Columbia University                             4
# 100                     Cornell University                             4
# 184                     Harvard University                             4
# 312  Massachusetts Institute of Technology                             4
# 432                   Princeton University                             4
# 511                    Stanford University                             4
# 627     University of California, Berkeley                             4
# 637                University of Cambridge                             4
# 648                  University of Chicago                             4
# 819                   University of Oxford                             4
# 999                        Yale University                             4
#
#      University Education Quality Average
# 53                                83.1750
# 96                                90.1550
# 100                               80.8175
# 184                              100.0000
# 312                               94.8375
# 432                               85.6625
# 511                               95.2975
# 627                               87.1775
# 637                               92.7150
# 648                               83.9275
# 819                               92.2125
# 999                               83.1725

# %%
popular_university_df.sort_values('University Education Quality Average', ascending=False)#sorting top universities
# Out:
#                                institution  University Education Quality  \
# 184                     Harvard University                             4
# 511                    Stanford University                             4
# 312  Massachusetts Institute of Technology                             4
# 637                University of Cambridge                             4
# 819                   University of Oxford                             4
# 96                     Columbia University                             4
# 627     University of California, Berkeley                             4
# 432                   Princeton University                             4
# 648                  University of Chicago                             4
# 53      California Institute of Technology                             4
# 999                        Yale University                             4
# 100                     Cornell University                             4
#
#      University Education Quality Average
# 184                              100.0000
# 511                               95.2975
# 312                               94.8375
# 637                               92.7150
# 819                               92.2125
# 96                                90.1550
# 627                               87.1775
# 432                               85.6625
# 648                               83.9275
# 53                                83.1750
# 999                               83.1725
# 100                               80.8175

# %%
popular_university_df=popular_university_df.merge(university, on='institution').drop_duplicates('institution')#All details of top universities
popular_university_df
# Out:
#                               institution  University Education Quality  \
# 0      California Institute of Technology                             4
# 4                     Columbia University                             4
# 8                      Cornell University                             4
# 12                     Harvard University                             4
# 16  Massachusetts Institute of Technology                             4
# 20                   Princeton University                             4
# 24                    Stanford University                             4
# 28     University of California, Berkeley                             4
# 32                University of Cambridge                             4
# 36                  University of Chicago                             4
# 40                   University of Oxford                             4
# 44                        Yale University                             4
#
#     University Education Quality Average  world_rank         country  \
# 0                                83.1750           5             USA
# 4                                90.1550           9             USA
# 8                                80.8175          12             USA
# 12                              100.0000           1             USA
# 16                               94.8375           2             USA
# 20                               85.6625           6             USA
# 24                               95.2975           3             USA
# 28                               87.1775          10             USA
# 32                               92.7150           4  United Kingdom
# 36                               83.9275          11             USA
# 40                               92.2125           7  United Kingdom
# 44                               83.1725           8             USA
#
#     national_rank  quality_of_education  alumni_employment  \
# 0               4                     2                 29
# 4               7                    23                 21
# 8              10                    21                 42
# 12              1                     7                  9
# 16              2                     9                 17
# 20              5                     8                 14
# 24              3                    17                 11
# 28              8                    16                 52
# 32              1                    10                 24
# 36              9                    15                 26
# 40              2                    13                 28
# 44              6                    14                 31
#
#     quality_of_faculty  publications  influence  citations  broad_impact  \
# 0                    7            37         22         22           NaN
# 4                   10            13         12         14           NaN
# 8                   14            22         21         16           NaN
# 12                   1             1          1          1           NaN
# 16                   3            12          4          4           NaN
# 20                   2            53         33         26           NaN
# 24                   5             4          2          2           NaN
# 28                   6             6          5          3           NaN
# 32                   4            16         16         11           NaN
# 36                   8            34         20         28           NaN
# 40                   9            15         13         19           NaN
# 44                  12            14          6         15           NaN
#
#     patents   score  year
# 0        18   85.21  2012
# 4         5   78.86  2012
# 8        10   73.69  2012
# 12        5  100.00  2012
# 16        1   91.67  2012
# 20      101   82.50  2012
# 24       15   89.50  2012
# 28       16   78.55  2012
# 32       50   86.17  2012
# 36      101   73.82  2012
# 40       26   82.34  2012
# 44       66   79.14  2012

# %%
from sklearn.metrics.pairwise import cosine_similarity #used to find similar universities
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Check for NaN or infinity values in the DataFrame
columns_with_nan = popular_university_df.columns[popular_university_df.isna().any()].tolist()
columns_with_inf = popular_university_df.columns[(popular_university_df == np.inf).any()].tolist()

print("Columns with NaN values:", columns_with_nan)
print("Columns with Infinity values:", columns_with_inf)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_10860\1035552205.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   popular_university_df.fillna(popular_university_df.mean(), inplace=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [23], in <cell line: 5>()
#       2 popular_university_df.fillna(popular_university_df.mean(), inplace=True)
#       4 # Compute cosine similarity
# ----> 5 similarity_score = cosine_similarity(popular_university_df[['University Education Quality', 'University Education Quality Average', 'world_rank', 'national_rank', 'quality_of_education', 'alumni_employment', 'quality_of_faculty', 'publications', 'influence', 'citations', 'broad_impact', 'patents', 'score', 'year']])
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:1251, in cosine_similarity(X, Y, dense_output)
#    1217 """Compute cosine similarity between samples in X and Y.
#    1218
#    1219 Cosine similarity, or the cosine kernel, computes similarity as the
#    (...)
#    1247 kernel matrix : ndarray of shape (n_samples_X, n_samples_Y)
#    1248 """
#    1249 # to avoid recursive import
# -> 1251 X, Y = check_pairwise_arrays(X, Y)
#    1253 X_normalized = normalize(X, copy=True)
#    1254 if X is Y:
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:147, in check_pairwise_arrays(X, Y, precomputed, dtype, accept_sparse, force_all_finite, copy)
#     144     dtype = dtype_float
#     146 if Y is X or Y is None:
# --> 147     X = Y = check_array(
#     148         X,
#     149         accept_sparse=accept_sparse,
#     150         dtype=dtype,
#     151         copy=copy,
#     152         force_all_finite=force_all_finite,
#     153         estimator=estimator,
#     154     )
#     155 else:
#     156     X = check_array(
#     157         X,
#     158         accept_sparse=accept_sparse,
#    (...)
#     162         estimator=estimator,
#     163     )
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:800, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     794         raise ValueError(
#     795             "Found array with dim %d. %s expected <= 2."
#     796             % (array.ndim, estimator_name)
#     797         )
#     799     if force_all_finite:
# --> 800         _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#     802 if ensure_min_samples > 0:
#     803     n_samples = _num_samples(array)
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:114, in _assert_all_finite(X, allow_nan, msg_dtype)
#     107     if (
#     108         allow_nan
#     109         and np.isinf(X).any()
#     110         or not allow_nan
#     111         and not np.isfinite(X).all()
#     112     ):
#     113         type_err = "infinity" if allow_nan else "NaN, infinity"
# --> 114         raise ValueError(
#     115             msg_err.format(
#     116                 type_err, msg_dtype if msg_dtype is not None else X.dtype
#     117             )
#     118         )
#     119 # for object dtype data, we only check for NaNs (GH-13254)
#     120 elif X.dtype == np.dtype("object") and not allow_nan:
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
similarity_score #915x915, 1 rows similarity with all other rows

# %%
popular_university_df.sort_values(by='University Education Quality Average', ascending=False)

# %%
def recommendation(institution_name, top_n=10):
    try:
        institution_name = institution_name.strip().lower()  # Preprocessing input
        
        # Find similar institution names in lowercase
        similar_names = university['institution'].str.strip().str.lower().str.contains(institution_name)
        
        # Check for similarity
        if similar_names.any():
            index = similar_names[similar_names].index[0] 
            similarity_scores = similarity_score[index]
            similar_indices = similarity_scores.argsort()[::-1][1:top_n+1]
            
            print(f"Universities similar to {university.loc[index, 'institution']}:")
            for i in similar_indices:
                print(university.loc[university.index[i], 'institution'])
        else:
            print(f"No similar universities found for {institution_name.capitalize()}")
    except IndexError:
        print(f"No similar universities found for {institution_name.capitalize()}")

# %%
    recommendation("University of Florida")
